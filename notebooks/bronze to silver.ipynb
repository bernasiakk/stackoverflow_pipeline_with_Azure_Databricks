# %% [markdown]
# ### List contents of bronze/silver/gold mounts:

# %%
print('BRONZE:')
files = dbutils.fs.ls('/mnt/stackoverflow/bronze/')

file_paths = [file.path for file in files]

for path in file_paths:
    print(path)
print('')

print('SILVER:')
files = dbutils.fs.ls('/mnt/stackoverflow/silver/')

file_paths = [file.path for file in files]

for path in file_paths:
    print(path)
print('')

print('GOLD:')
files = dbutils.fs.ls('/mnt/stackoverflow/gold/')

file_paths = [file.path for file in files]

for path in file_paths:
    print(path)
# Out:
# BRONZE:
# dbfs:/mnt/stackoverflow/bronze/genai/
# dbfs:/mnt/stackoverflow/bronze/genai.stackexchange.com.7z
# dbfs:/mnt/stackoverflow/bronze/health/
# dbfs:/mnt/stackoverflow/bronze/health.stackexchange.com.7z
# dbfs:/mnt/stackoverflow/bronze/iot/
# dbfs:/mnt/stackoverflow/bronze/iot.stackexchange.com.7z
# dbfs:/mnt/stackoverflow/bronze/lifehacks.stackexchange.com.7z
#
# SILVER:
#
# GOLD:

# %% [markdown]
# ### Make a list of all .xml files extracted from stackoverflow archive:

# %%
from databricks_filesystem import DatabricksFilesystem

adb_fs = DatabricksFilesystem(dbutils=dbutils)

file_list = adb_fs.filesystem_list(filesystem_path="/mnt/stackoverflow/bronze/")

xml_files = []

for file in file_list:
    if '.xml' in file:
        xml_files.append(file)

# %% [markdown]
# ### Transform and Load
# 1. Make transformations:
# - remove leading '_' from column names
# - add 'Category' column (with fixed value)
# - Clean up "free text" columns (i.e., AboutMe, Body, etc.)
#
# 2. Then write df's into silver layer.

# %%
from bs4 import BeautifulSoup
from pyspark.sql.functions import lit, udf, col, substring
from pyspark.sql.types import StringType, VarcharType
import html
import re

# Function to clean HTML content
def clean_html_column(text):
    if text is not None:
        return ' '.join(html.unescape(text).split())
    return text
# Register UDF
clean_html_udf = udf(clean_html_column, StringType())

# Compile a regex pattern to convert CamelCase to snake_case
pattern = re.compile(r"(?<=[a-z])(?=[A-Z])|(?<=[A-Z])(?=[A-Z][a-z])")

# Function to transform column name
def transform_column_name(col_name):
    # Remove leading underscore, if present
    if col_name.startswith('_'):
        col_name = col_name[1:]
    
    # Convert CamelCase to snake_case
    col_name = pattern.sub('_', col_name).lower()
    
    return col_name

for file in xml_files:
    print('')
    print(f"STARTING TRANSFORMATION FOR {file}")
    df = spark.read.option("rowTag", 'row').format("xml").load(file) #str(file.split('/')[-1].split('.')[0].lower())
    # remove leading '_' from column names
    for c in df.columns:
        new_col_name = transform_column_name(c)
        df = df.withColumnRenamed(c, new_col_name)
    print(df.schema)
    # add 'Category' column (with fixed value)
    df = df.withColumn('category', lit(str(file.split('/')[-2].lower())))
    # clean up free text columns (AboutMe, Text, etc.)
    columns_to_check = ['about_me', 'text', 'body']
    columns_present = [c for c in columns_to_check if c in df.columns]
    if columns_present:
        for c in columns_present:
            print(f"col {c} exists. Cleaning {c}")
            df = df.withColumn(c, substring(col(c), 1, 255))
            df = df.withColumn(c, clean_html_udf(df[c]))
            df = df.withColumn(c, df[c].cast(VarcharType(255)))
            print(f"col {c} cleaned.")
    else:
        print("No matching columns found.")
    dest = f'/mnt/stackoverflow/silver/{file.split("/")[-2]}/{file.split("/")[-1].split(".")[0].lower()}/' #/dbfs
    df.write.format("delta").mode("overwrite").option("mergeSchema", "true").save(dest)
    print(f'TRANSFORMATION COMPLETED FOR {file}. FILE WRITTEN TO {dest}')
    print('')
# Out:
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/genai/Badges.xml
# StructType([StructField('class', LongType(), True), StructField('date', TimestampType(), True), StructField('id', LongType(), True), StructField('name', StringType(), True), StructField('tag_based', BooleanType(), True), StructField('user_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/genai/Badges.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/genai/badges/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/genai/Comments.xml
# StructType([StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_id', LongType(), True), StructField('score', LongType(), True), StructField('text', StringType(), True), StructField('user_display_name', StringType(), True), StructField('user_id', LongType(), True)])
# col text exists. Cleaning text
# col text cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/genai/Comments.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/genai/comments/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/genai/PostHistory.xml
# StructType([StructField('comment', StringType(), True), StructField('content_license', StringType(), True), StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_history_type_id', LongType(), True), StructField('post_id', LongType(), True), StructField('revision_guid', StringType(), True), StructField('text', StringType(), True), StructField('user_display_name', StringType(), True), StructField('user_id', LongType(), True)])
# col text exists. Cleaning text
# col text cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/genai/PostHistory.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/genai/posthistory/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/genai/PostLinks.xml
# StructType([StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('link_type_id', LongType(), True), StructField('post_id', LongType(), True), StructField('related_post_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/genai/PostLinks.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/genai/postlinks/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/genai/Posts.xml
# StructType([StructField('accepted_answer_id', LongType(), True), StructField('answer_count', LongType(), True), StructField('body', StringType(), True), StructField('closed_date', TimestampType(), True), StructField('comment_count', LongType(), True), StructField('community_owned_date', TimestampType(), True), StructField('content_license', StringType(), True), StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('last_activity_date', TimestampType(), True), StructField('last_edit_date', TimestampType(), True), StructField('last_editor_display_name', StringType(), True), StructField('last_editor_user_id', LongType(), True), StructField('owner_display_name', StringType(), True), StructField('owner_user_id', LongType(), True), StructField('parent_id', LongType(), True), StructField('post_type_id', LongType(), True), StructField('score', LongType(), True), StructField('tags', StringType(), True), StructField('title', StringType(), True), StructField('view_count', LongType(), True)])
# col body exists. Cleaning body
# col body cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/genai/Posts.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/genai/posts/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/genai/Tags.xml
# StructType([StructField('count', LongType(), True), StructField('excerpt_post_id', LongType(), True), StructField('id', LongType(), True), StructField('tag_name', StringType(), True), StructField('wiki_post_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/genai/Tags.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/genai/tags/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/genai/Users.xml
# StructType([StructField('about_me', StringType(), True), StructField('account_id', LongType(), True), StructField('creation_date', TimestampType(), True), StructField('display_name', StringType(), True), StructField('down_votes', LongType(), True), StructField('id', LongType(), True), StructField('last_access_date', TimestampType(), True), StructField('location', StringType(), True), StructField('reputation', LongType(), True), StructField('up_votes', LongType(), True), StructField('views', LongType(), True), StructField('website_url', StringType(), True)])
# col about_me exists. Cleaning about_me
# col about_me cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/genai/Users.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/genai/users/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/genai/Votes.xml
# StructType([StructField('bounty_amount', LongType(), True), StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_id', LongType(), True), StructField('user_id', LongType(), True), StructField('vote_type_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/genai/Votes.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/genai/votes/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/health/Badges.xml
# StructType([StructField('class', LongType(), True), StructField('date', TimestampType(), True), StructField('id', LongType(), True), StructField('name', StringType(), True), StructField('tag_based', BooleanType(), True), StructField('user_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/health/Badges.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/health/badges/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/health/Comments.xml
# StructType([StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_id', LongType(), True), StructField('score', LongType(), True), StructField('text', StringType(), True), StructField('user_display_name', StringType(), True), StructField('user_id', LongType(), True)])
# col text exists. Cleaning text
# col text cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/health/Comments.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/health/comments/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/health/PostHistory.xml
# StructType([StructField('comment', StringType(), True), StructField('content_license', StringType(), True), StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_history_type_id', LongType(), True), StructField('post_id', LongType(), True), StructField('revision_guid', StringType(), True), StructField('text', StringType(), True), StructField('user_display_name', StringType(), True), StructField('user_id', LongType(), True)])
# col text exists. Cleaning text
# col text cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/health/PostHistory.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/health/posthistory/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/health/PostLinks.xml
# StructType([StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('link_type_id', LongType(), True), StructField('post_id', LongType(), True), StructField('related_post_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/health/PostLinks.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/health/postlinks/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/health/Posts.xml
# StructType([StructField('accepted_answer_id', LongType(), True), StructField('answer_count', LongType(), True), StructField('body', StringType(), True), StructField('closed_date', TimestampType(), True), StructField('comment_count', LongType(), True), StructField('community_owned_date', TimestampType(), True), StructField('content_license', StringType(), True), StructField('creation_date', TimestampType(), True), StructField('favorite_count', LongType(), True), StructField('id', LongType(), True), StructField('last_activity_date', TimestampType(), True), StructField('last_edit_date', TimestampType(), True), StructField('last_editor_display_name', StringType(), True), StructField('last_editor_user_id', LongType(), True), StructField('owner_display_name', StringType(), True), StructField('owner_user_id', LongType(), True), StructField('parent_id', LongType(), True), StructField('post_type_id', LongType(), True), StructField('score', LongType(), True), StructField('tags', StringType(), True), StructField('title', StringType(), True), StructField('view_count', LongType(), True)])
# col body exists. Cleaning body
# col body cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/health/Posts.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/health/posts/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/health/Tags.xml
# StructType([StructField('count', LongType(), True), StructField('excerpt_post_id', LongType(), True), StructField('id', LongType(), True), StructField('tag_name', StringType(), True), StructField('wiki_post_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/health/Tags.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/health/tags/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/health/Users.xml
# StructType([StructField('about_me', StringType(), True), StructField('account_id', LongType(), True), StructField('creation_date', TimestampType(), True), StructField('display_name', StringType(), True), StructField('down_votes', LongType(), True), StructField('id', LongType(), True), StructField('last_access_date', TimestampType(), True), StructField('location', StringType(), True), StructField('reputation', LongType(), True), StructField('up_votes', LongType(), True), StructField('views', LongType(), True), StructField('website_url', StringType(), True)])
# col about_me exists. Cleaning about_me
# col about_me cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/health/Users.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/health/users/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/health/Votes.xml
# StructType([StructField('bounty_amount', LongType(), True), StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_id', LongType(), True), StructField('user_id', LongType(), True), StructField('vote_type_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/health/Votes.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/health/votes/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/iot/Badges.xml
# StructType([StructField('class', LongType(), True), StructField('date', TimestampType(), True), StructField('id', LongType(), True), StructField('name', StringType(), True), StructField('tag_based', BooleanType(), True), StructField('user_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/iot/Badges.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/iot/badges/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/iot/Comments.xml
# StructType([StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_id', LongType(), True), StructField('score', LongType(), True), StructField('text', StringType(), True), StructField('user_display_name', StringType(), True), StructField('user_id', LongType(), True)])
# col text exists. Cleaning text
# col text cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/iot/Comments.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/iot/comments/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/iot/PostHistory.xml
# StructType([StructField('comment', StringType(), True), StructField('content_license', StringType(), True), StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_history_type_id', LongType(), True), StructField('post_id', LongType(), True), StructField('revision_guid', StringType(), True), StructField('text', StringType(), True), StructField('user_display_name', StringType(), True), StructField('user_id', LongType(), True)])
# col text exists. Cleaning text
# col text cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/iot/PostHistory.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/iot/posthistory/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/iot/PostLinks.xml
# StructType([StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('link_type_id', LongType(), True), StructField('post_id', LongType(), True), StructField('related_post_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/iot/PostLinks.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/iot/postlinks/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/iot/Posts.xml
# StructType([StructField('accepted_answer_id', LongType(), True), StructField('answer_count', LongType(), True), StructField('body', StringType(), True), StructField('closed_date', TimestampType(), True), StructField('comment_count', LongType(), True), StructField('community_owned_date', TimestampType(), True), StructField('content_license', StringType(), True), StructField('creation_date', TimestampType(), True), StructField('favorite_count', LongType(), True), StructField('id', LongType(), True), StructField('last_activity_date', TimestampType(), True), StructField('last_edit_date', TimestampType(), True), StructField('last_editor_display_name', StringType(), True), StructField('last_editor_user_id', LongType(), True), StructField('owner_display_name', StringType(), True), StructField('owner_user_id', LongType(), True), StructField('parent_id', LongType(), True), StructField('post_type_id', LongType(), True), StructField('score', LongType(), True), StructField('tags', StringType(), True), StructField('title', StringType(), True), StructField('view_count', LongType(), True)])
# col body exists. Cleaning body
# col body cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/iot/Posts.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/iot/posts/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/iot/Tags.xml
# StructType([StructField('count', LongType(), True), StructField('excerpt_post_id', LongType(), True), StructField('id', LongType(), True), StructField('tag_name', StringType(), True), StructField('wiki_post_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/iot/Tags.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/iot/tags/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/iot/Users.xml
# StructType([StructField('about_me', StringType(), True), StructField('account_id', LongType(), True), StructField('creation_date', TimestampType(), True), StructField('display_name', StringType(), True), StructField('down_votes', LongType(), True), StructField('id', LongType(), True), StructField('last_access_date', TimestampType(), True), StructField('location', StringType(), True), StructField('reputation', LongType(), True), StructField('up_votes', LongType(), True), StructField('views', LongType(), True), StructField('website_url', StringType(), True)])
# col about_me exists. Cleaning about_me
# col about_me cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/iot/Users.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/iot/users/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/iot/Votes.xml
# StructType([StructField('bounty_amount', LongType(), True), StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_id', LongType(), True), StructField('user_id', LongType(), True), StructField('vote_type_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/iot/Votes.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/iot/votes/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/Badges.xml
# StructType([StructField('class', LongType(), True), StructField('date', TimestampType(), True), StructField('id', LongType(), True), StructField('name', StringType(), True), StructField('tag_based', BooleanType(), True), StructField('user_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/Badges.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/lifehacks/badges/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/Comments.xml
# StructType([StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_id', LongType(), True), StructField('score', LongType(), True), StructField('text', StringType(), True), StructField('user_display_name', StringType(), True), StructField('user_id', LongType(), True)])
# col text exists. Cleaning text
# col text cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/Comments.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/lifehacks/comments/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/PostHistory.xml
# StructType([StructField('comment', StringType(), True), StructField('content_license', StringType(), True), StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_history_type_id', LongType(), True), StructField('post_id', LongType(), True), StructField('revision_guid', StringType(), True), StructField('text', StringType(), True), StructField('user_display_name', StringType(), True), StructField('user_id', LongType(), True)])
# col text exists. Cleaning text
# col text cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/PostHistory.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/lifehacks/posthistory/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/PostLinks.xml
# StructType([StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('link_type_id', LongType(), True), StructField('post_id', LongType(), True), StructField('related_post_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/PostLinks.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/lifehacks/postlinks/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/Posts.xml
# StructType([StructField('accepted_answer_id', LongType(), True), StructField('answer_count', LongType(), True), StructField('body', StringType(), True), StructField('closed_date', TimestampType(), True), StructField('comment_count', LongType(), True), StructField('community_owned_date', TimestampType(), True), StructField('content_license', StringType(), True), StructField('creation_date', TimestampType(), True), StructField('favorite_count', LongType(), True), StructField('id', LongType(), True), StructField('last_activity_date', TimestampType(), True), StructField('last_edit_date', TimestampType(), True), StructField('last_editor_display_name', StringType(), True), StructField('last_editor_user_id', LongType(), True), StructField('owner_display_name', StringType(), True), StructField('owner_user_id', LongType(), True), StructField('parent_id', LongType(), True), StructField('post_type_id', LongType(), True), StructField('score', LongType(), True), StructField('tags', StringType(), True), StructField('title', StringType(), True), StructField('view_count', LongType(), True)])
# col body exists. Cleaning body
# col body cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/Posts.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/lifehacks/posts/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/Tags.xml
# StructType([StructField('count', LongType(), True), StructField('excerpt_post_id', LongType(), True), StructField('id', LongType(), True), StructField('tag_name', StringType(), True), StructField('wiki_post_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/Tags.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/lifehacks/tags/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/Users.xml
# StructType([StructField('about_me', StringType(), True), StructField('account_id', LongType(), True), StructField('creation_date', TimestampType(), True), StructField('display_name', StringType(), True), StructField('down_votes', LongType(), True), StructField('id', LongType(), True), StructField('last_access_date', TimestampType(), True), StructField('location', StringType(), True), StructField('reputation', LongType(), True), StructField('up_votes', LongType(), True), StructField('views', LongType(), True), StructField('website_url', StringType(), True)])
# col about_me exists. Cleaning about_me
# col about_me cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/Users.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/lifehacks/users/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/Votes.xml
# StructType([StructField('bounty_amount', LongType(), True), StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_id', LongType(), True), StructField('user_id', LongType(), True), StructField('vote_type_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/lifehacks/Votes.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/lifehacks/votes/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/opendata/Badges.xml
# StructType([StructField('class', LongType(), True), StructField('date', TimestampType(), True), StructField('id', LongType(), True), StructField('name', StringType(), True), StructField('tag_based', BooleanType(), True), StructField('user_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/opendata/Badges.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/opendata/badges/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/opendata/Comments.xml
# StructType([StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_id', LongType(), True), StructField('score', LongType(), True), StructField('text', StringType(), True), StructField('user_display_name', StringType(), True), StructField('user_id', LongType(), True)])
# col text exists. Cleaning text
# col text cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/opendata/Comments.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/opendata/comments/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/opendata/PostHistory.xml
# StructType([StructField('comment', StringType(), True), StructField('content_license', StringType(), True), StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_history_type_id', LongType(), True), StructField('post_id', LongType(), True), StructField('revision_guid', StringType(), True), StructField('text', StringType(), True), StructField('user_display_name', StringType(), True), StructField('user_id', LongType(), True)])
# col text exists. Cleaning text
# col text cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/opendata/PostHistory.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/opendata/posthistory/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/opendata/PostLinks.xml
# StructType([StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('link_type_id', LongType(), True), StructField('post_id', LongType(), True), StructField('related_post_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/opendata/PostLinks.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/opendata/postlinks/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/opendata/Posts.xml
# StructType([StructField('accepted_answer_id', LongType(), True), StructField('answer_count', LongType(), True), StructField('body', StringType(), True), StructField('closed_date', TimestampType(), True), StructField('comment_count', LongType(), True), StructField('community_owned_date', TimestampType(), True), StructField('content_license', StringType(), True), StructField('creation_date', TimestampType(), True), StructField('favorite_count', LongType(), True), StructField('id', LongType(), True), StructField('last_activity_date', TimestampType(), True), StructField('last_edit_date', TimestampType(), True), StructField('last_editor_display_name', StringType(), True), StructField('last_editor_user_id', LongType(), True), StructField('owner_display_name', StringType(), True), StructField('owner_user_id', LongType(), True), StructField('parent_id', LongType(), True), StructField('post_type_id', LongType(), True), StructField('score', LongType(), True), StructField('tags', StringType(), True), StructField('title', StringType(), True), StructField('view_count', LongType(), True)])
# col body exists. Cleaning body
# col body cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/opendata/Posts.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/opendata/posts/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/opendata/Tags.xml
# StructType([StructField('count', LongType(), True), StructField('excerpt_post_id', LongType(), True), StructField('id', LongType(), True), StructField('tag_name', StringType(), True), StructField('wiki_post_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/opendata/Tags.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/opendata/tags/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/opendata/Users.xml
# StructType([StructField('about_me', StringType(), True), StructField('account_id', LongType(), True), StructField('creation_date', TimestampType(), True), StructField('display_name', StringType(), True), StructField('down_votes', LongType(), True), StructField('id', LongType(), True), StructField('last_access_date', TimestampType(), True), StructField('location', StringType(), True), StructField('reputation', LongType(), True), StructField('up_votes', LongType(), True), StructField('views', LongType(), True), StructField('website_url', StringType(), True)])
# col about_me exists. Cleaning about_me
# col about_me cleaned.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/opendata/Users.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/opendata/users/
#
#
# STARTING TRANSFORMATION FOR dbfs:/mnt/stackoverflow/bronze/opendata/Votes.xml
# StructType([StructField('bounty_amount', LongType(), True), StructField('creation_date', TimestampType(), True), StructField('id', LongType(), True), StructField('post_id', LongType(), True), StructField('user_id', LongType(), True), StructField('vote_type_id', LongType(), True)])
# No matching columns found.
# TRANSFORMATION COMPLETED FOR dbfs:/mnt/stackoverflow/bronze/opendata/Votes.xml. FILE WRITTEN TO /mnt/stackoverflow/silver/opendata/votes/
